# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.00,high=90.00,size=2000)
lngs = np.random.uniform(low=-90.00,high=90.00,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
from citipy import citipy




# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# YOUR CODE HERE
# Out:
# 774

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country= city_weather["sys"]["country"]
        city_wdescription = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')   
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_wdescription,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | westport
# Processing Record 2 of Set 1 | codrington
# Processing Record 3 of Set 1 | koprivstica
# Processing Record 4 of Set 1 | antalaha
# Processing Record 5 of Set 1 | rincon
# Processing Record 6 of Set 1 | khakhea
# Processing Record 7 of Set 1 | vardo
# Processing Record 8 of Set 1 | miraflores
# Processing Record 9 of Set 1 | trincomalee
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | arya
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | bonthe
# Processing Record 15 of Set 1 | banda aceh
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | appleton
# Processing Record 18 of Set 1 | luderitz
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | axim
# Processing Record 21 of Set 1 | sakakah
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | kuusamo
# Processing Record 24 of Set 1 | hope mills
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | saint-joseph
# Processing Record 27 of Set 1 | hella
# Processing Record 28 of Set 1 | abha
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | wawina
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | bilma
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 1 | coquimbo
# Processing Record 36 of Set 1 | am timan
# Processing Record 37 of Set 1 | saldanha
# Processing Record 38 of Set 1 | viedma
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | bereda
# Processing Record 42 of Set 1 | sao filipe
# Processing Record 43 of Set 1 | alvorada
# Processing Record 44 of Set 1 | klaksvik
# Processing Record 45 of Set 1 | kavaratti
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | sao joao da barra
# Processing Record 48 of Set 1 | raudeberg
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 2 | ajdabiya
# Processing Record 4 of Set 2 | humberto de campos
# Processing Record 5 of Set 2 | dhidhdhoo
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | kasongo-lunda
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | aguimes
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | berikulskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | mindelo
# Processing Record 13 of Set 2 | sikonge
# Processing Record 14 of Set 2 | winneba
# Processing Record 15 of Set 2 | murray
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | elliot
# Processing Record 18 of Set 2 | saint-louis
# Processing Record 19 of Set 2 | saquarema
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | wickede
# Processing Record 24 of Set 2 | sorland
# Processing Record 25 of Set 2 | yarkovo
# Processing Record 26 of Set 2 | aswan
# Processing Record 27 of Set 2 | dingle
# Processing Record 28 of Set 2 | sarab
# Processing Record 29 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 2 | kashi
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | margate
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | manturovo
# Processing Record 35 of Set 2 | lagoa
# Processing Record 36 of Set 2 | verdalsora
# City not found. Skipping...
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | darovskoy
# Processing Record 39 of Set 2 | general roca
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | caravelas
# Processing Record 42 of Set 2 | tshikapa
# Processing Record 43 of Set 2 | rocha
# Processing Record 44 of Set 2 | bridgewater
# Processing Record 45 of Set 2 | rusape
# Processing Record 46 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 47 of Set 2 | calderitas
# Processing Record 48 of Set 2 | the valley
# Processing Record 49 of Set 2 | megion
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | den helder
# Processing Record 2 of Set 3 | nuuk
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | qom
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | provins
# Processing Record 7 of Set 3 | bathsheba
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | sfantu gheorghe
# Processing Record 10 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | marsh harbour
# Processing Record 13 of Set 3 | husavik
# Processing Record 14 of Set 3 | jaen
# Processing Record 15 of Set 3 | zheleznodorozhnyy
# Processing Record 16 of Set 3 | jamame
# Processing Record 17 of Set 3 | polunochnoye
# Processing Record 18 of Set 3 | noyabrsk
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | nizhniy baskunchak
# Processing Record 21 of Set 3 | yayva
# Processing Record 22 of Set 3 | laje
# Processing Record 23 of Set 3 | cubuk
# Processing Record 24 of Set 3 | masvingo
# Processing Record 25 of Set 3 | tahta
# Processing Record 26 of Set 3 | liapades
# City not found. Skipping...
# Processing Record 27 of Set 3 | tessalit
# Processing Record 28 of Set 3 | shihezi
# Processing Record 29 of Set 3 | piskavica
# Processing Record 30 of Set 3 | shache
# Processing Record 31 of Set 3 | road town
# Processing Record 32 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 3 | razole
# Processing Record 34 of Set 3 | matay
# Processing Record 35 of Set 3 | mezhdurechensk
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | lebrija
# Processing Record 38 of Set 3 | uribia
# Processing Record 39 of Set 3 | sarny
# Processing Record 40 of Set 3 | ostrovnoy
# Processing Record 41 of Set 3 | punta arenas
# Processing Record 42 of Set 3 | vigrestad
# Processing Record 43 of Set 3 | peiting
# Processing Record 44 of Set 3 | manta
# Processing Record 45 of Set 3 | barra do corda
# Processing Record 46 of Set 3 | marsa matruh
# Processing Record 47 of Set 3 | qandala
# Processing Record 48 of Set 3 | akonolinga
# Processing Record 49 of Set 3 | inhambane
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | chicama
# Processing Record 2 of Set 4 | kargasok
# Processing Record 3 of Set 4 | rudbar
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 4 | modasa
# Processing Record 6 of Set 4 | kifri
# Processing Record 7 of Set 4 | utinga
# Processing Record 8 of Set 4 | beloha
# Processing Record 9 of Set 4 | sensuntepeque
# Processing Record 10 of Set 4 | setermoen
# Processing Record 11 of Set 4 | manyana
# Processing Record 12 of Set 4 | cidreira
# Processing Record 13 of Set 4 | gat
# Processing Record 14 of Set 4 | filadelfia
# Processing Record 15 of Set 4 | sur
# Processing Record 16 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | oriximina
# Processing Record 18 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 4 | pisco
# Processing Record 20 of Set 4 | hauterive
# Processing Record 21 of Set 4 | puerto ayora
# Processing Record 22 of Set 4 | gamba
# Processing Record 23 of Set 4 | maraa
# Processing Record 24 of Set 4 | richards bay
# Processing Record 25 of Set 4 | divnomorskoye
# Processing Record 26 of Set 4 | turinsk
# Processing Record 27 of Set 4 | cefalu
# Processing Record 28 of Set 4 | sisimiut
# Processing Record 29 of Set 4 | raahe
# Processing Record 30 of Set 4 | severnoye
# Processing Record 31 of Set 4 | grand gaube
# Processing Record 32 of Set 4 | gornyak
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | buraydah
# Processing Record 35 of Set 4 | gurlan
# Processing Record 36 of Set 4 | shushtar
# Processing Record 37 of Set 4 | khipro
# Processing Record 38 of Set 4 | faya
# Processing Record 39 of Set 4 | san cristobal
# Processing Record 40 of Set 4 | belmonte
# Processing Record 41 of Set 4 | mafinga
# Processing Record 42 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 4 | sandnessjoen
# Processing Record 44 of Set 4 | filingue
# Processing Record 45 of Set 4 | ambovombe
# Processing Record 46 of Set 4 | riyadh
# Processing Record 47 of Set 4 | fez
# Processing Record 48 of Set 4 | el ejido
# Processing Record 49 of Set 4 | itaituba
# Processing Record 50 of Set 4 | alenquer
# Processing Record 1 of Set 5 | cockburn town
# Processing Record 2 of Set 5 | derzhavinsk
# Processing Record 3 of Set 5 | bentiu
# Processing Record 4 of Set 5 | cochrane
# Processing Record 5 of Set 5 | talnakh
# Processing Record 6 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 5 | port elizabeth
# Processing Record 8 of Set 5 | ler
# Processing Record 9 of Set 5 | magaria
# Processing Record 10 of Set 5 | atar
# Processing Record 11 of Set 5 | saint anthony
# Processing Record 12 of Set 5 | west bay
# Processing Record 13 of Set 5 | maltahohe
# Processing Record 14 of Set 5 | olafsvik
# Processing Record 15 of Set 5 | palasa
# Processing Record 16 of Set 5 | umm ruwabah
# City not found. Skipping...
# Processing Record 17 of Set 5 | rawson
# Processing Record 18 of Set 5 | muros
# Processing Record 19 of Set 5 | bluefields
# Processing Record 20 of Set 5 | san carlos de bariloche
# Processing Record 21 of Set 5 | longyearbyen
# Processing Record 22 of Set 5 | puerto carreno
# Processing Record 23 of Set 5 | bubaque
# Processing Record 24 of Set 5 | vizinga
# Processing Record 25 of Set 5 | betsiamites
# Processing Record 26 of Set 5 | dzaoudzi
# Processing Record 27 of Set 5 | bansang
# Processing Record 28 of Set 5 | kulhudhuffushi
# Processing Record 29 of Set 5 | mozhaysk
# Processing Record 30 of Set 5 | ambilobe
# Processing Record 31 of Set 5 | ipixuna
# Processing Record 32 of Set 5 | rudraprayag
# Processing Record 33 of Set 5 | ponta do sol
# Processing Record 34 of Set 5 | iralaya
# Processing Record 35 of Set 5 | guider
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | alghero
# Processing Record 38 of Set 5 | jaszarokszallas
# Processing Record 39 of Set 5 | mintlaw
# Processing Record 40 of Set 5 | arshan
# Processing Record 41 of Set 5 | copiapo
# Processing Record 42 of Set 5 | charlottesville
# Processing Record 43 of Set 5 | hobyo
# Processing Record 44 of Set 5 | dera din panah
# City not found. Skipping...
# Processing Record 45 of Set 5 | clyde river
# Processing Record 46 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 5 | vestmannaeyjar
# Processing Record 49 of Set 5 | caraballeda
# Processing Record 50 of Set 5 | paita
# Processing Record 1 of Set 6 | piranshahr
# Processing Record 2 of Set 6 | coihaique
# Processing Record 3 of Set 6 | zhezkazgan
# Processing Record 4 of Set 6 | lubango
# Processing Record 5 of Set 6 | oussouye
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | mantua
# Processing Record 8 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | anzio
# Processing Record 10 of Set 6 | shahr-e babak
# Processing Record 11 of Set 6 | skelleftea
# Processing Record 12 of Set 6 | vilkija
# Processing Record 13 of Set 6 | aljezur
# Processing Record 14 of Set 6 | saint-augustin
# Processing Record 15 of Set 6 | crepaja
# Processing Record 16 of Set 6 | roald
# Processing Record 17 of Set 6 | naryan-mar
# Processing Record 18 of Set 6 | muscat
# Processing Record 19 of Set 6 | salinopolis
# Processing Record 20 of Set 6 | porto torres
# Processing Record 21 of Set 6 | fougamou
# Processing Record 22 of Set 6 | cap-aux-meules
# Processing Record 23 of Set 6 | adrar
# Processing Record 24 of Set 6 | aranda de duero
# Processing Record 25 of Set 6 | oum hadjer
# Processing Record 26 of Set 6 | anloga
# Processing Record 27 of Set 6 | camopi
# Processing Record 28 of Set 6 | quatre cocos
# Processing Record 29 of Set 6 | scarborough
# Processing Record 30 of Set 6 | pagman
# City not found. Skipping...
# Processing Record 31 of Set 6 | vangaindrano
# Processing Record 32 of Set 6 | severomorsk
# Processing Record 33 of Set 6 | mecca
# Processing Record 34 of Set 6 | nantucket
# Processing Record 35 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 6 | lasa
# Processing Record 38 of Set 6 | los llanos de aridane
# Processing Record 39 of Set 6 | toulepleu
# City not found. Skipping...
# Processing Record 40 of Set 6 | jam sahib
# Processing Record 41 of Set 6 | toila
# Processing Record 42 of Set 6 | bojnurd
# Processing Record 43 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 44 of Set 6 | mumford
# Processing Record 45 of Set 6 | porto walter
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | tuymazy
# Processing Record 48 of Set 6 | jega
# Processing Record 49 of Set 6 | marienburg
# Processing Record 50 of Set 6 | tocopilla
# Processing Record 1 of Set 7 | marawi
# Processing Record 2 of Set 7 | castro
# Processing Record 3 of Set 7 | rock falls
# Processing Record 4 of Set 7 | marabba
# Processing Record 5 of Set 7 | mangrol
# Processing Record 6 of Set 7 | taperoa
# Processing Record 7 of Set 7 | ferry pass
# Processing Record 8 of Set 7 | elliot lake
# Processing Record 9 of Set 7 | masumbwe
# Processing Record 10 of Set 7 | kalisz
# Processing Record 11 of Set 7 | korla
# Processing Record 12 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 13 of Set 7 | torbay
# Processing Record 14 of Set 7 | vvedenskoye
# Processing Record 15 of Set 7 | dulce nombre de culmi
# Processing Record 16 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 7 | arcachon
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | la rioja
# Processing Record 20 of Set 7 | buchanan
# Processing Record 21 of Set 7 | havoysund
# Processing Record 22 of Set 7 | north myrtle beach
# Processing Record 23 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 7 | rocky mount
# Processing Record 25 of Set 7 | vestmanna
# Processing Record 26 of Set 7 | staryy nadym
# Processing Record 27 of Set 7 | arlit
# Processing Record 28 of Set 7 | ayaviri
# Processing Record 29 of Set 7 | ambikapur
# Processing Record 30 of Set 7 | soyo
# Processing Record 31 of Set 7 | boa vista
# Processing Record 32 of Set 7 | ilulissat
# Processing Record 33 of Set 7 | turayf
# Processing Record 34 of Set 7 | inongo
# Processing Record 35 of Set 7 | lunino
# Processing Record 36 of Set 7 | nargana
# Processing Record 37 of Set 7 | stornoway
# Processing Record 38 of Set 7 | murdochville
# Processing Record 39 of Set 7 | camacha
# Processing Record 40 of Set 7 | saint-leu
# Processing Record 41 of Set 7 | nador
# Processing Record 42 of Set 7 | port hawkesbury
# Processing Record 43 of Set 7 | traverse city
# Processing Record 44 of Set 7 | carnarvon
# Processing Record 45 of Set 7 | carutapera
# Processing Record 46 of Set 7 | general pico
# Processing Record 47 of Set 7 | ankpa
# Processing Record 48 of Set 7 | ercis
# Processing Record 49 of Set 7 | cabinda
# Processing Record 50 of Set 7 | brigantine
# Processing Record 1 of Set 8 | hofn
# Processing Record 2 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 8 | saint-francois
# Processing Record 4 of Set 8 | wazirganj
# Processing Record 5 of Set 8 | sovetskiy
# Processing Record 6 of Set 8 | cayenne
# Processing Record 7 of Set 8 | talcahuano
# Processing Record 8 of Set 8 | beyneu
# Processing Record 9 of Set 8 | sena madureira
# Processing Record 10 of Set 8 | epanomi
# Processing Record 11 of Set 8 | akropong
# Processing Record 12 of Set 8 | novomalorossiyskaya
# Processing Record 13 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 14 of Set 8 | rovaniemi
# Processing Record 15 of Set 8 | rozhyshche
# Processing Record 16 of Set 8 | bertoua
# Processing Record 17 of Set 8 | cleethorpes
# Processing Record 18 of Set 8 | oranjestad
# Processing Record 19 of Set 8 | paamiut
# Processing Record 20 of Set 8 | altay
# Processing Record 21 of Set 8 | kosh-agach
# Processing Record 22 of Set 8 | bandarbeyla
# Processing Record 23 of Set 8 | laguna
# Processing Record 24 of Set 8 | muli
# Processing Record 25 of Set 8 | jagdalpur
# Processing Record 26 of Set 8 | pancas
# Processing Record 27 of Set 8 | rafaela
# Processing Record 28 of Set 8 | itarantim
# Processing Record 29 of Set 8 | san juan
# Processing Record 30 of Set 8 | nioro
# Processing Record 31 of Set 8 | dakar
# Processing Record 32 of Set 8 | pasrur
# Processing Record 33 of Set 8 | saint-pierre
# Processing Record 34 of Set 8 | burica
# City not found. Skipping...
# Processing Record 35 of Set 8 | san rafael
# Processing Record 36 of Set 8 | sokolo
# Processing Record 37 of Set 8 | diego de almagro
# Processing Record 38 of Set 8 | kemijarvi
# Processing Record 39 of Set 8 | mitsamiouli
# Processing Record 40 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 8 | salihorsk
# Processing Record 42 of Set 8 | bam
# Processing Record 43 of Set 8 | brae
# Processing Record 44 of Set 8 | miranda
# Processing Record 45 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | lorca
# Processing Record 48 of Set 8 | necochea
# Processing Record 49 of Set 8 | hearst
# Processing Record 50 of Set 8 | bellefontaine
# Processing Record 1 of Set 9 | constitucion
# Processing Record 2 of Set 9 | puerto concordia
# Processing Record 3 of Set 9 | camabatela
# Processing Record 4 of Set 9 | lardos
# Processing Record 5 of Set 9 | gazanjyk
# Processing Record 6 of Set 9 | york
# Processing Record 7 of Set 9 | vyshkov
# Processing Record 8 of Set 9 | soledade
# Processing Record 9 of Set 9 | marzuq
# Processing Record 10 of Set 9 | omboue
# Processing Record 11 of Set 9 | azrow
# City not found. Skipping...
# Processing Record 12 of Set 9 | cacalchen
# Processing Record 13 of Set 9 | alta floresta
# Processing Record 14 of Set 9 | kamina
# Processing Record 15 of Set 9 | tallahassee
# Processing Record 16 of Set 9 | vieux-habitants
# Processing Record 17 of Set 9 | yining
# Processing Record 18 of Set 9 | amapa
# Processing Record 19 of Set 9 | chapais
# Processing Record 20 of Set 9 | goito
# Processing Record 21 of Set 9 | mazara del vallo
# Processing Record 22 of Set 9 | san borja
# Processing Record 23 of Set 9 | nedjo
# Processing Record 24 of Set 9 | cacoal
# Processing Record 25 of Set 9 | taltal
# Processing Record 26 of Set 9 | ghanzi
# Processing Record 27 of Set 9 | irtyshskiy
# Processing Record 28 of Set 9 | cabedelo
# Processing Record 29 of Set 9 | palmas de monte alto
# Processing Record 30 of Set 9 | gravdal
# Processing Record 31 of Set 9 | maragogi
# Processing Record 32 of Set 9 | chipinge
# Processing Record 33 of Set 9 | mercedes
# Processing Record 34 of Set 9 | henties bay
# Processing Record 35 of Set 9 | sao jose da coroa grande
# Processing Record 36 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 37 of Set 9 | axixa do tocantins
# City not found. Skipping...
# Processing Record 38 of Set 9 | ippy
# Processing Record 39 of Set 9 | vila velha
# Processing Record 40 of Set 9 | chapleau
# Processing Record 41 of Set 9 | torbat-e jam
# Processing Record 42 of Set 9 | santa cruz de la palma
# Processing Record 43 of Set 9 | wilmington
# Processing Record 44 of Set 9 | puerto del rosario
# Processing Record 45 of Set 9 | san andres
# Processing Record 46 of Set 9 | iquitos
# Processing Record 47 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 9 | ayagoz
# Processing Record 49 of Set 9 | podgornoye
# Processing Record 50 of Set 9 | la sarre
# Processing Record 1 of Set 10 | bonfim
# Processing Record 2 of Set 10 | taoudenni
# Processing Record 3 of Set 10 | sol-iletsk
# Processing Record 4 of Set 10 | maraba
# Processing Record 5 of Set 10 | venado tuerto
# Processing Record 6 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 10 | lincoln
# Processing Record 8 of Set 10 | borba
# Processing Record 9 of Set 10 | togui
# City not found. Skipping...
# Processing Record 10 of Set 10 | lukovetskiy
# Processing Record 11 of Set 10 | inta
# Processing Record 12 of Set 10 | sinnamary
# Processing Record 13 of Set 10 | loubomo
# Processing Record 14 of Set 10 | jesup
# Processing Record 15 of Set 10 | abu kamal
# Processing Record 16 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 10 | nanga eboko
# Processing Record 18 of Set 10 | fereydun kenar
# Processing Record 19 of Set 10 | alberton
# Processing Record 20 of Set 10 | abu samrah
# Processing Record 21 of Set 10 | yabelo
# Processing Record 22 of Set 10 | tingrela
# City not found. Skipping...
# Processing Record 23 of Set 10 | itarema
# Processing Record 24 of Set 10 | awbari
# Processing Record 25 of Set 10 | cordoba
# Processing Record 26 of Set 10 | jalu
# Processing Record 27 of Set 10 | barcelos
# Processing Record 28 of Set 10 | ugoofaaru
# Processing Record 29 of Set 10 | hambantota
# Processing Record 30 of Set 10 | potsdam
# Processing Record 31 of Set 10 | garowe
# Processing Record 32 of Set 10 | banihal
# Processing Record 33 of Set 10 | diffa
# Processing Record 34 of Set 10 | isla mujeres
# Processing Record 35 of Set 10 | mahajanga
# Processing Record 36 of Set 10 | salalah
# Processing Record 37 of Set 10 | tete
# Processing Record 38 of Set 10 | ladson
# Processing Record 39 of Set 10 | ellsworth
# Processing Record 40 of Set 10 | atbasar
# Processing Record 41 of Set 10 | ankara
# Processing Record 42 of Set 10 | dioknisi
# Processing Record 43 of Set 10 | aragarcas
# Processing Record 44 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 10 | havelock
# Processing Record 46 of Set 10 | rey bouba
# Processing Record 47 of Set 10 | shilovo
# Processing Record 48 of Set 10 | lodwar
# Processing Record 49 of Set 10 | esna
# Processing Record 50 of Set 10 | acopiara
# Processing Record 1 of Set 11 | midland
# Processing Record 2 of Set 11 | pangody
# Processing Record 3 of Set 11 | tibati
# Processing Record 4 of Set 11 | manavgat
# Processing Record 5 of Set 11 | tiruvannamalai
# Processing Record 6 of Set 11 | gboko
# Processing Record 7 of Set 11 | kudahuvadhoo
# Processing Record 8 of Set 11 | gemena
# Processing Record 9 of Set 11 | mkushi
# Processing Record 10 of Set 11 | prainha
# Processing Record 11 of Set 11 | julio de castilhos
# Processing Record 12 of Set 11 | dharchula
# Processing Record 13 of Set 11 | diez
# Processing Record 14 of Set 11 | soma
# Processing Record 15 of Set 11 | larsnes
# Processing Record 16 of Set 11 | yar-sale
# Processing Record 17 of Set 11 | valparaiso
# Processing Record 18 of Set 11 | madras
# Processing Record 19 of Set 11 | nieuw amsterdam
# Processing Record 20 of Set 11 | rio maior
# Processing Record 21 of Set 11 | thompson
# Processing Record 22 of Set 11 | oranjemund
# Processing Record 23 of Set 11 | houma
# Processing Record 24 of Set 11 | san julian
# Processing Record 25 of Set 11 | pangnirtung
# Processing Record 26 of Set 11 | uyuni
# Processing Record 27 of Set 11 | dwarka
# Processing Record 28 of Set 11 | gulu
# Processing Record 29 of Set 11 | bykovo
# Processing Record 30 of Set 11 | santarem
# Processing Record 31 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 32 of Set 11 | upata
# Processing Record 33 of Set 11 | san pedro de macoris
# Processing Record 34 of Set 11 | kampene
# Processing Record 35 of Set 11 | jumla
# Processing Record 36 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 11 | praia da vitoria
# Processing Record 38 of Set 11 | macau
# Processing Record 39 of Set 11 | olinda
# Processing Record 40 of Set 11 | placido de castro
# Processing Record 41 of Set 11 | palaikastron
# Processing Record 42 of Set 11 | liepaja
# Processing Record 43 of Set 11 | balkanabat
# Processing Record 44 of Set 11 | cururupu
# Processing Record 45 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 46 of Set 11 | morondava
# Processing Record 47 of Set 11 | togur
# Processing Record 48 of Set 11 | harbour breton
# Processing Record 49 of Set 11 | hualmay
# Processing Record 50 of Set 11 | takoradi
# Processing Record 1 of Set 12 | serebryansk
# Processing Record 2 of Set 12 | najran
# Processing Record 3 of Set 12 | svetlyy
# Processing Record 4 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 5 of Set 12 | meerzorg
# City not found. Skipping...
# Processing Record 6 of Set 12 | karakose
# City not found. Skipping...
# Processing Record 7 of Set 12 | yegorlykskaya
# Processing Record 8 of Set 12 | spokoynaya
# Processing Record 9 of Set 12 | herat
# Processing Record 10 of Set 12 | chokwe
# Processing Record 11 of Set 12 | baracoa
# Processing Record 12 of Set 12 | tucurui
# Processing Record 13 of Set 12 | waddan
# Processing Record 14 of Set 12 | nalut
# Processing Record 15 of Set 12 | trapani
# Processing Record 16 of Set 12 | othonoi
# City not found. Skipping...
# Processing Record 17 of Set 12 | nouakchott
# Processing Record 18 of Set 12 | south river
# Processing Record 19 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 20 of Set 12 | maceio
# Processing Record 21 of Set 12 | antofagasta
# Processing Record 22 of Set 12 | teteven
# Processing Record 23 of Set 12 | jiwani
# Processing Record 24 of Set 12 | turukhansk
# Processing Record 25 of Set 12 | kasangulu
# Processing Record 26 of Set 12 | navashino
# Processing Record 27 of Set 12 | shelburne
# Processing Record 28 of Set 12 | manoel urbano
# Processing Record 29 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 30 of Set 12 | idlib
# Processing Record 31 of Set 12 | kesinga
# Processing Record 32 of Set 12 | plettenberg bay
# Processing Record 33 of Set 12 | menongue
# Processing Record 34 of Set 12 | awjilah
# Processing Record 35 of Set 12 | catamarca
# Processing Record 36 of Set 12 | peru
# Processing Record 37 of Set 12 | ritchie
# Processing Record 38 of Set 12 | nouadhibou
# Processing Record 39 of Set 12 | joshimath
# Processing Record 40 of Set 12 | lindi
# Processing Record 41 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 12 | cap malheureux
# Processing Record 43 of Set 12 | marsaxlokk
# Processing Record 44 of Set 12 | gao
# Processing Record 45 of Set 12 | concarneau
# Processing Record 46 of Set 12 | kirkwall
# Processing Record 47 of Set 12 | luau
# Processing Record 48 of Set 12 | renfrew
# Processing Record 49 of Set 12 | maniitsoq
# Processing Record 50 of Set 12 | padang
# Processing Record 1 of Set 13 | strezhevoy
# Processing Record 2 of Set 13 | moen
# Processing Record 3 of Set 13 | rena
# Processing Record 4 of Set 13 | goderich
# Processing Record 5 of Set 13 | matsanga
# City not found. Skipping...
# Processing Record 6 of Set 13 | synya
# Processing Record 7 of Set 13 | comodoro rivadavia
# Processing Record 8 of Set 13 | puerto narino
# Processing Record 9 of Set 13 | bud
# Processing Record 10 of Set 13 | ikom
# Processing Record 11 of Set 13 | bjelovar
# Processing Record 12 of Set 13 | dhadar
# Processing Record 13 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 14 of Set 13 | namsos
# Processing Record 15 of Set 13 | zlobin
# Processing Record 16 of Set 13 | columbia
# Processing Record 17 of Set 13 | emba
# Processing Record 18 of Set 13 | tabuk
# Processing Record 19 of Set 13 | sychevka
# Processing Record 20 of Set 13 | lake city
# Processing Record 21 of Set 13 | bokoro
# Processing Record 22 of Set 13 | faaborg
# Processing Record 23 of Set 13 | bamako
# Processing Record 24 of Set 13 | dalvik
# Processing Record 25 of Set 13 | ouahigouya
# Processing Record 26 of Set 13 | baijiantan
# Processing Record 27 of Set 13 | castro-urdiales
# Processing Record 28 of Set 13 | mazsalaca
# Processing Record 29 of Set 13 | dasoguz
# Processing Record 30 of Set 13 | chagoda
# Processing Record 31 of Set 13 | arona
# Processing Record 32 of Set 13 | taylorville
# Processing Record 33 of Set 13 | envira
# Processing Record 34 of Set 13 | westonaria
# Processing Record 35 of Set 13 | benguela
# Processing Record 36 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 13 | khokhryaki
# Processing Record 38 of Set 13 | vuktyl
# Processing Record 39 of Set 13 | thinadhoo
# Processing Record 40 of Set 13 | bonavista
# Processing Record 41 of Set 13 | ceyhan
# Processing Record 42 of Set 13 | gobabis
# Processing Record 43 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 13 | uarini
# Processing Record 45 of Set 13 | beisfjord
# Processing Record 46 of Set 13 | narasannapeta
# Processing Record 47 of Set 13 | ayabaca
# Processing Record 48 of Set 13 | grand-santi
# Processing Record 49 of Set 13 | koulamoutou
# Processing Record 50 of Set 13 | banamba
# Processing Record 1 of Set 14 | lucea
# Processing Record 2 of Set 14 | borama
# City not found. Skipping...
# Processing Record 3 of Set 14 | veraval
# Processing Record 4 of Set 14 | bandundu
# Processing Record 5 of Set 14 | ourossogui
# Processing Record 6 of Set 14 | golpayegan
# Processing Record 7 of Set 14 | chake chake
# Processing Record 8 of Set 14 | lambarene
# Processing Record 9 of Set 14 | wagar
# Processing Record 10 of Set 14 | acarau
# Processing Record 11 of Set 14 | igrim
# Processing Record 12 of Set 14 | vologda
# Processing Record 13 of Set 14 | treuchtlingen
# Processing Record 14 of Set 14 | yarensk
# Processing Record 15 of Set 14 | ampanihy
# Processing Record 16 of Set 14 | impfondo
# Processing Record 17 of Set 14 | bulawayo
# Processing Record 18 of Set 14 | treinta y tres
# Processing Record 19 of Set 14 | tazovskiy
# Processing Record 20 of Set 14 | honningsvag
# Processing Record 21 of Set 14 | lima
# Processing Record 22 of Set 14 | aketi
# Processing Record 23 of Set 14 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 24 of Set 14 | sawakin
# Processing Record 25 of Set 14 | sao bento
# Processing Record 26 of Set 14 | bela vista do paraiso
# Processing Record 27 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 28 of Set 14 | molina
# Processing Record 29 of Set 14 | campoverde
# Processing Record 30 of Set 14 | qibili
# City not found. Skipping...
# Processing Record 31 of Set 14 | landerneau
# Processing Record 32 of Set 14 | tabou
# Processing Record 33 of Set 14 | bafq
# Processing Record 34 of Set 14 | umm lajj
# Processing Record 35 of Set 14 | iquique
# Processing Record 36 of Set 14 | pedernales
# Processing Record 37 of Set 14 | neuquen
# Processing Record 38 of Set 14 | krasnoselkup
# Processing Record 39 of Set 14 | santa rosa
# Processing Record 40 of Set 14 | kisarawe
# Processing Record 41 of Set 14 | marechal deodoro
# Processing Record 42 of Set 14 | santa vitoria do palmar
# Processing Record 43 of Set 14 | manosque
# Processing Record 44 of Set 14 | ribeira brava
# Processing Record 45 of Set 14 | sechura
# Processing Record 46 of Set 14 | santiago del estero
# Processing Record 47 of Set 14 | straumen
# Processing Record 48 of Set 14 | segou
# Processing Record 49 of Set 14 | sabha
# Processing Record 50 of Set 14 | springs
# Processing Record 1 of Set 15 | saverne
# Processing Record 2 of Set 15 | bosaso
# Processing Record 3 of Set 15 | ostersund
# Processing Record 4 of Set 15 | kapoeta
# Processing Record 5 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 6 of Set 15 | senador jose porfirio
# Processing Record 7 of Set 15 | inirida
# Processing Record 8 of Set 15 | achisay
# City not found. Skipping...
# Processing Record 9 of Set 15 | villa carlos paz
# Processing Record 10 of Set 15 | barmer
# Processing Record 11 of Set 15 | elat
# Processing Record 12 of Set 15 | livingston
# Processing Record 13 of Set 15 | makungu
# Processing Record 14 of Set 15 | turkistan
# Processing Record 15 of Set 15 | gainesville
# Processing Record 16 of Set 15 | amilly
# Processing Record 17 of Set 15 | moyale
# Processing Record 18 of Set 15 | karpogory
# Processing Record 19 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 15 | siniscola
# Processing Record 21 of Set 15 | leningradskiy
# Processing Record 22 of Set 15 | landeck
# Processing Record 23 of Set 15 | hendek
# Processing Record 24 of Set 15 | aspindza
# Processing Record 25 of Set 15 | nguruka
# Processing Record 26 of Set 15 | raga
# Processing Record 27 of Set 15 | eregli
# Processing Record 28 of Set 15 | semnan
# Processing Record 29 of Set 15 | xghajra
# City not found. Skipping...
# Processing Record 30 of Set 15 | rognedino
# Processing Record 31 of Set 15 | mollendo
# Processing Record 32 of Set 15 | iranshahr
# Processing Record 33 of Set 15 | jibuti
# Processing Record 34 of Set 15 | praia
# Processing Record 35 of Set 15 | quba
# Processing Record 36 of Set 15 | weligama
# Processing Record 37 of Set 15 | bali
# Processing Record 38 of Set 15 | kayunga
# Processing Record 39 of Set 15 | ilo
# Processing Record 40 of Set 15 | vitkov
# Processing Record 41 of Set 15 | san carlos
# Processing Record 42 of Set 15 | pachino
# Processing Record 43 of Set 15 | camenca
# Processing Record 44 of Set 15 | sokoni
# Processing Record 45 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 46 of Set 15 | sirsa
# Processing Record 47 of Set 15 | vila franca do campo
# Processing Record 48 of Set 15 | karlshamn
# Processing Record 49 of Set 15 | santa isabel do rio negro
# Processing Record 50 of Set 15 | karaton
# Processing Record 1 of Set 16 | matara
# Processing Record 2 of Set 16 | schruns
# Processing Record 3 of Set 16 | colquechaca
# Processing Record 4 of Set 16 | piacabucu
# Processing Record 5 of Set 16 | polyarnyy
# Processing Record 6 of Set 16 | colares
# Processing Record 7 of Set 16 | ancud
# Processing Record 8 of Set 16 | zawiercie
# Processing Record 9 of Set 16 | manzil tamim
# City not found. Skipping...
# Processing Record 10 of Set 16 | kerrabe
# City not found. Skipping...
# Processing Record 11 of Set 16 | monterotondo
# Processing Record 12 of Set 16 | igarka
# Processing Record 13 of Set 16 | kyzyl-suu
# Processing Record 14 of Set 16 | rio gallegos
# Processing Record 15 of Set 16 | issia
# Processing Record 16 of Set 16 | wiwili
# Processing Record 17 of Set 16 | fonte boa
# Processing Record 18 of Set 16 | misratah
# Processing Record 19 of Set 16 | dalbandin
# Processing Record 20 of Set 16 | francisco beltrao
# Processing Record 21 of Set 16 | kimberley
# Processing Record 22 of Set 16 | villiers
# Processing Record 23 of Set 16 | magnitka
# Processing Record 24 of Set 16 | kazalinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 703

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Westport  41.1415  -73.3579     66.88        59          61        1.01
# 1   Codrington -38.2667  141.9667     45.09        95          98        7.29
# 2  Koprivstica  43.2349   22.6205     55.62       100           1        4.92
# 3     Antalaha -14.9003   50.2788     65.70        82           0        7.87
# 4       Rincon  32.2960  -81.2354     65.86        59         100       18.41
# 5      Khakhea -24.6895   23.4940     70.09        28           5       11.34
# 6        Vardo  70.3705   31.1107     44.58        87           0        6.91
# 7   Miraflores  19.2167  -98.8083     68.04        56          81        4.00
# 8  Trincomalee   8.5711   81.2335     80.82        76          96       21.85
# 9    Cape Town -33.9258   18.4232     62.10        84           0        8.05
#
#   Country Current Description                 Date
# 0      US       broken clouds  2022-09-29 20:01:12
# 1      AU     overcast clouds  2022-09-29 19:54:40
# 2      RS           clear sky  2022-09-29 20:01:12
# 3      MG           clear sky  2022-09-29 19:53:14
# 4      US     overcast clouds  2022-09-29 20:00:36
# 5      BW           clear sky  2022-09-29 20:01:13
# 6      NO           clear sky  2022-09-29 20:01:14
# 7      MX       broken clouds  2022-09-29 20:01:15
# 8      LK     overcast clouds  2022-09-29 20:01:15
# 9      ZA           clear sky  2022-09-29 19:57:23

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df=city_data_df[new_column_order]
# Display sample data
# YOUR CODE HERE
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Westport      US  41.1415  -73.3579     66.88        59          61
# 1   Codrington      AU -38.2667  141.9667     45.09        95          98
# 2  Koprivstica      RS  43.2349   22.6205     55.62       100           1
# 3     Antalaha      MG -14.9003   50.2788     65.70        82           0
# 4       Rincon      US  32.2960  -81.2354     65.86        59         100
#
#    Wind Speed Current Description
# 0        1.01       broken clouds
# 1        7.29     overcast clouds
# 2        4.92           clear sky
# 3        7.87           clear sky
# 4       18.41     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label="City ID")
# YOUR CODE HERE
